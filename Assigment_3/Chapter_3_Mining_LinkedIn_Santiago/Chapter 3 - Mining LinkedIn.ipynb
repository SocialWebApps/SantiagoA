# %% [markdown]
# #Mining the Social Web, 2nd Edition
#
# ##Chapter 3: Mining LinkedIn: Faceting Job Titles, Clustering Colleagues, and More
#
# This IPython Notebook provides an interactive way to follow along with and explore the numbered examples from [_Mining the Social Web (2nd Edition)_](http://bit.ly/135dHfs). The intent behind this notebook is to reinforce the concepts from the sample code in a fun, convenient, and effective way. This notebook assumes that you are reading along with the book and have the context of the discussion as you work through these exercises.
#
# In the somewhat unlikely event that you've somehow stumbled across this notebook outside of its context on GitHub, [you can find the full source code repository here](http://bit.ly/16kGNyb).
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# #LinkedIn API Access
#
# LinkedIn implements OAuth 2.0 as one of its standard authentication mechanisms, but still supports OAuth 1.0a, which provides you with four credentials ("API Key", "Secret Key", "OAuth User Token", and "OAuth User Secret") that can be used to gain instant API access with no further fuss or redirections. You can create an app and retrieve these four credentials through the "Developer" section of your account settings as shown below or by navigating directly to https://www.linkedin.com/secure/developer.
#
# <img src="files/resources/ch03-linkedin/images/LinkedIn-app.png" width="600px">

# %% [markdown]
# Note that you'll need to install a third-party package called <code>python-linkedin</code> to use the code in this notebook. Installing a package directly from a GitHub repository is easy with pip in the terminal:
#
# <code>
# $ pip install python-linkedin
# </code>

# %% [markdown]
# ## Example 1. Using LinkedIn OAuth credentials to receive an access token suitable for development and accessing your own data

# %%
from linkedin import linkedin # pip install python-linkedin

# Define CONSUMER_KEY, CONSUMER_SECRET,  
# USER_TOKEN, and USER_SECRET from the credentials 
# provided in your LinkedIn application

CONSUMER_KEY = '78kks1enwsc7yv'
CONSUMER_SECRET = '8YKcqvbKd0kxUzfB'
USER_TOKEN = 'a7315e10-97e0-42ef-ae16-bf3071eb5d62'
USER_SECRET = 'b16a9524-4927-422e-801c-2da0fc763db3'

RETURN_URL = '' # Not required for developer authentication

# Instantiate the developer authentication class

auth = linkedin.LinkedInDeveloperAuthentication(CONSUMER_KEY, CONSUMER_SECRET, 
                                USER_TOKEN, USER_SECRET, 
                                RETURN_URL, 
                                permissions=linkedin.PERMISSIONS.enums.values())

# Pass it in to the app...

app = linkedin.LinkedInApplication(auth)

# Use the app...

app.get_profile()
# Out:
# {u'firstName': u'Santiago',
#  u'headline': u'Student at FAU',
#  u'id': u'mc3jSoWvbZ',
#  u'lastName': u'Aguerrevere',
#  u'siteStandardProfileRequest': {u'url': u'https://www.linkedin.com/profile/view?id=398377245&authType=name&authToken=Cbd-&trk=api*a4057084*s4122704*'}}

# %% [markdown]
# ## Example 2. Retrieving your LinkedIn connections and storing them to disk

# %%
import json

connections = app.get_connections()

#save the connections data in a file called "linkedin_connections.json" in the resources folder
connections_data = 'resources/linkedin_connections.json'

f = open(connections_data, 'w')
f.write(json.dumps(connections, indent=1))
f.close()

# You can reuse the data without using the API later like this...
# connections = json.loads(open(connections_data).read())

# %%
# Execute this cell if you need to reload data...
import json
connections = json.loads(open('resources/linkedin_connections.json').read())

# %% [markdown]
# **Note**: Should you need to revoke account access from your application or any other OAuth application, you can do so at [https://www.linkedin.com/secure/settings?userAgree=&goback=%2Enas_*1_*1_*1](https://www.linkedin.com/secure/settings?userAgree=&goback=%2Enas_*1_*1_*1)

# %% [markdown]
# ## Example 3. Pretty-printing your LinkedIn connections' data

# %%
from prettytable import PrettyTable # pip install prettytable

pt = PrettyTable(field_names=['Name', 'Location'])
pt.align = 'l'

[ pt.add_row((c['firstName'] + ' ' + c['lastName'], c['location']['name'])) 
  for c in connections['values']
      if c.has_key('location')]

print pt
# Out:
# +----------------------------+-------------------------------+
# | Name                       | Location                      |
# +----------------------------+-------------------------------+
# | Andres Pena                | Miami/Fort Lauderdale Area    |
# | Silvia Morales             | Miami/Fort Lauderdale Area    |
# | Rodd Sheradsky, PA         | Miami/Fort Lauderdale Area    |
# | Juan Andres Benatuil Wulff | Miami/Fort Lauderdale Area    |
# | Rakesh Reddy               | Miami/Fort Lauderdale Area    |
# | Malissa Augustin           | Miami/Fort Lauderdale Area    |
# | Ravi Shankar               | West Palm Beach, Florida Area |
# | Annie Wang                 | China                         |
# | Eric Deleuze               | Miami/Fort Lauderdale Area    |
# | Melissa Serrano            | West Palm Beach, Florida Area |
# | Kevin Medina               | Greater Milwaukee Area        |
# | Debra Lewis                | West Palm Beach, Florida Area |
# | cbaechle fau               | Albany, New York Area         |
# +----------------------------+-------------------------------+

# %% [markdown]
# ## Example 4. Displaying job position history for your profile and a connection's profile

# %%
import json

# See http://developer.linkedin.com/documents/profile-fields#fullprofile
# for details on additional field selectors that can be passed in for
# retrieving additional profile information.

# Display your own positions...
print "My positions:"
my_positions = app.get_profile(selectors=['positions'])
print json.dumps(my_positions, indent=1)

# Display positions for someone in your network...
print
print "Someone else's positions: "
# Get an id for a connection. We'll just pick the second one (first one had no positions listed)
connection_id = connections['values'][1]['id']
connection_positions = app.get_profile(member_id=connection_id, selectors=['positions'])
print json.dumps(connection_positions, indent=1)
# Out:
# My positions:
# {
#  "positions": {
#   "_total": 0
#  }
# }
# Someone else's positions:
# {
#  "positions": {
#   "_total": 1,
#   "values": [
#    {
#     "startDate": {
#      "year": 2013,
#      "month": 3
#     },
#     "title": "Marketing & Communications Leader for the Caribbean Region",
#     "company": {
#      "name": "PROCOLOMBIA"
#     },
#     "summary": "Supervise all marketing logistics for event and trade show participation for the Caribbean office of Procolombia, including media plans and other sponsorship opportunities within said events and in regional media.\n\nCoordinate the development of all marketing materials, kits, promotional merchandise, ads for brand positioning and remembrance of Colombia in the Caribbean.\n\nManage the relationship and daily follow-up with Ogilvy, Procolombia\u2019s PR agency, to review and develop projects.\n\nOrganize media tours for the director of ProColombia for the Caribbean to meet with top media in the region to discuss trade, tourism and investment opportunities in Colombia.\n\nDevelop press releases for the promotion of Colombia as a world-class destination for trade, investment and tourism.\n\nResearch and generate content for www.Colombia.Travel Twitter account, ProColombia\u2019s tourism portal.\n\nOrganize press trips for Caribbean media and bloggers to visit Colombia and generate publications and Social Media content in tourism and other topics that promote the country.",
#     "isCurrent": true,
#     "id": 384164708
#    }
#   ]
#  }
# }

# %% [markdown]
# ## Example 5. Using field selector syntax to request additional details for APIs

# %%
# See http://developer.linkedin.com/documents/understanding-field-selectors
# for more information on the field selector syntax

my_positions = app.get_profile(selectors=['positions:(company:(name,industry,id))'])
print json.dumps(my_positions, indent=1)
# Out:
# {
#  "positions": {
#   "_total": 0
#  }
# }

# %% [markdown]
# ## Example 6. Simple normalization of company suffixes from address book data

# %%
import os
import csv
from collections import Counter
from operator import itemgetter
from prettytable import PrettyTable

# XXX: The "Outlook CSV" formatted file of connections from 
# http://www.linkedin.com/people/export-settings is at the following
# location: resources/my-linkedin/my_connections.csv

CSV_FILE = os.path.join("resources", "my_connections_comb.csv")

# Define a set of transforms that converts the first item
# to the second item. Here, we're simply handling some
# commonly known abbreviations, stripping off common suffixes, 
# etc.

transforms = [(', Inc.', ''), (', Inc', ''), (', LLC', ''), (', LLP', ''),
               (' LLC', ''), (' Inc.', ''), (' Inc', '')]

csvReader = csv.DictReader(open(CSV_FILE), delimiter=',', quotechar='"')
contacts = [row for row in csvReader]
companies = [c['Company'].strip() for c in contacts if c['Company'].strip() != '']

for i, _ in enumerate(companies):
    for transform in transforms:
        companies[i] = companies[i].replace(*transform)

pt = PrettyTable(field_names=['Company', 'Freq'])
pt.align = 'l'
c = Counter(companies)
[pt.add_row([company, freq]) 
 for (company, freq) in sorted(c.items(), key=itemgetter(1), reverse=True) 
     if freq > 0] #changed to greater than 0 because my contacts list is so small, there were no company repeats
print pt
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-31-0346d5f54928> in <module>()
#      33  for (company, freq) in sorted(c.items(), key=itemgetter(1), reverse=True)
#      34      if freq > 0] #changed to greater than 0 because my contacts list is so small, there were no company repeats
# ---> 35 print pt
#
# C:\Anaconda\lib\site-packages\prettytable.pyc in __str__(self)
#     238     else:
#     239         def __str__(self):
# --> 240            return self.__unicode__().encode(self.encoding)
#     241
#     242     def __unicode__(self):
#
# C:\Anaconda\lib\site-packages\prettytable.pyc in __unicode__(self)
#     241
#     242     def __unicode__(self):
# --> 243         return self.get_string()
#     244
#     245     ##############################
#
# C:\Anaconda\lib\site-packages\prettytable.pyc in get_string(self, **kwargs)
#     985
#     986         # Turn all data in all rows into Unicode, formatted as desired
# --> 987         formatted_rows = self._format_rows(rows, options)
#     988
#     989         # Compute column widths
#
# C:\Anaconda\lib\site-packages\prettytable.pyc in _format_rows(self, rows, options)
#     940
#     941     def _format_rows(self, rows, options):
# --> 942         return [self._format_row(row, options) for row in rows]
#     943
#     944     ##############################
#
# C:\Anaconda\lib\site-packages\prettytable.pyc in _format_row(self, row, options)
#     937
#     938     def _format_row(self, row, options):
# --> 939         return [self._format_value(field, value) for (field, value) in zip(self._field_names, row)]
#     940
#     941     def _format_rows(self, rows, options):
#
# C:\Anaconda\lib\site-packages\prettytable.pyc in _format_value(self, field, value)
#     888         elif isinstance(value, float) and field in self._float_format:
#     889             value = self._unicode(("%%%sf" % self._float_format[field]) % value)
# --> 890         return self._unicode(value)
#     891
#     892     def _compute_widths(self, rows, options):
#
# C:\Anaconda\lib\site-packages\prettytable.pyc in _unicode(self, value)
#     179             value = str(value)
#     180         if not isinstance(value, unicode):
# --> 181             value = unicode(value, self.encoding, "strict")
#     182         return value
#     183
#
# C:\Anaconda\lib\encodings\utf_8.pyc in decode(input, errors)
#      14
#      15 def decode(input, errors='strict'):
# ---> 16     return codecs.utf_8_decode(input, errors, True)
#      17
#      18 class IncrementalEncoder(codecs.IncrementalEncoder):
#
# UnicodeDecodeError: 'utf8' codec can't decode byte 0xe0 in position 9: invalid continuation byte

# %% [markdown]
# ## Example 7. Standardizing common job titles and computing their frequencies

# %%
import os
import csv
from operator import itemgetter
from collections import Counter
from prettytable import PrettyTable

# XXX: The "Outlook CSV" formatted file of connections from 
# http://www.linkedin.com/people/export-settings is at the following
# location: resources/my-linkedin/my_connections.csv

CSV_FILE = os.path.join("resources", "my_connections_comb.csv")

transforms = [
    ('Sr.', 'Senior'),
    ('Sr', 'Senior'),
    ('Jr.', 'Junior'),
    ('Jr', 'Junior'),
    ('CEO', 'Chief Executive Officer'),
    ('COO', 'Chief Operating Officer'),
    ('CTO', 'Chief Technology Officer'),
    ('CFO', 'Chief Finance Officer'),
    ('VP', 'Vice President'),
    ]

csvReader = csv.DictReader(open(CSV_FILE), delimiter=',', quotechar='"')
contacts = [row for row in csvReader]

# Read in a list of titles and split apart
# any combined titles like "President/CEO."
# Other variations could be handled as well, such
# as "President & CEO", "President and CEO", etc.

titles = []
for contact in contacts:
    titles.extend([t.strip() for t in contact['Job Title'].split('/')
                  if contact['Job Title'].strip() != ''])

# Replace common/known abbreviations

for i, _ in enumerate(titles):
    for transform in transforms:
        titles[i] = titles[i].replace(*transform)

# Print out a table of titles sorted by frequency

pt = PrettyTable(field_names=['Title', 'Freq'])
pt.align = 'l'
c = Counter(titles)
[pt.add_row([title, freq]) 
 for (title, freq) in sorted(c.items(), key=itemgetter(1), reverse=True) 
     if freq > 0] # Changed to greater than 0 because contacts list is so small, there were no repeats
print pt

# Print out a table of tokens sorted by frequency

tokens = []
for title in titles:
    tokens.extend([t.strip(',') for t in title.split()])
pt = PrettyTable(field_names=['Token', 'Freq'])
pt.align = 'l'
c = Counter(tokens)
[pt.add_row([token, freq]) 
 for (token, freq) in sorted(c.items(), key=itemgetter(1), reverse=True) 
     if freq > 1 and len(token) > 2]
print pt
# Out:
# +------------------------------------------------------------------------------------------------+------+
# | Title                                                                                          | Freq |
# +------------------------------------------------------------------------------------------------+------+
# | Chief Executive Officer                                                                        | 10   |
# | Founder                                                                                        | 9    |
# | President                                                                                      | 9    |
# | Vice President                                                                                 | 8    |
# | Principal                                                                                      | 7    |
# | Managing Director                                                                              | 6    |
# | Board Member                                                                                   | 5    |
# | Partner                                                                                        | 4    |
# | President & Chief Executive Officer                                                            | 4    |
# | Co-Founder                                                                                     | 3    |
# | Advisor                                                                                        | 3    |
# | Adjunct Professor                                                                              | 2    |
# | Co Owner                                                                                       | 2    |
# | Senior Vice President                                                                          | 2    |
# | Chief Technology Officer                                                                       | 2    |
# | Co-founder                                                                                     | 2    |
# | Entrepreneur in Residence                                                                      | 2    |
# | Co-Founder, Chief Executive Officer                                                            | 2    |
# | Director, Research Park and Economic Development                                               | 1    |
# | Co-Founder, Steering Committee                                                                 | 1    |
# | Assoc. Director, IP                                                                            | 1    |
# | Venture Designer, Hybrid Zone X                                                                | 1    |
# | Vice President for Research                                                                    | 1    |
# | Energy Director                                                                                | 1    |
# | Energy Innovation Portal                                                                       | 1    |
# | Business Team                                                                                  | 1    |
# | Director, Advanced Vehicle Commercialization Policy                                            | 1    |
# | Corporate Board Director                                                                       | 1    |
# | Lecturer                                                                                       | 1    |
# | BME Doctoral Student & Research Assistant                                                      | 1    |
# | Civic Activist                                                                                 | 1    |
# | Project Development, Program Director for the Notre Dame Initiative on Global Development      | 1    |
# | Board Director                                                                                 | 1    |
# | Co-Founder & Director of STEM Integration                                                      | 1    |
# | Managing Editor, Defense Counsel Journal                                                       | 1    |
# | Venture Capitalist                                                                             | 1    |
# | Entrepreneurship Managing Director in Transition                                               | 1    |
# | Realtor "Top Producer"                                                                         | 1    |
# | User Experience Designer and Project Manager                                                   | 1    |
# | Chief of Transferrable Trust                                                                   | 1    |
# | Director, Market Development & Regulatory Affairs                                              | 1    |
# | Vice President, Engineering                                                                    | 1    |
# | Vice President Finance & Operations                                                            | 1    |
# | Co-Founder and President                                                                       | 1    |
# | Research administrator, ISEN                                                                   | 1    |
# | Senior Advisor for Technology & Innovation                                                     | 1    |
# | Vice President, Marketing & Business Development                                               | 1    |
# | Future Leadership Programme                                                                    | 1    |
# | Deputy Director                                                                                | 1    |
# | Director, Center for Advanced BioEnergy Research                                               | 1    |
# | Chief Marketing Officer                                                                        | 1    |
# | Co-founder and Managing Director                                                               | 1    |
# | Vice President, Business Development                                                           | 1    |
# | Mentor                                                                                         | 1    |
# | Special Assistant, Bureau of Energy Resources                                                  | 1    |
# | Acting Chairman and Board Member                                                               | 1    |
# | Deputy Sustainability Officer, Office of the Mayor                                             | 1    |
# | Program Manager, Illinois Cooperative Development Center                                       | 1    |
# | Eigenaar                                                                                       | 1    |
# | Member and Consultant                                                                          | 1    |
# | Global Operation Lead - Energy Efficiency                                                      | 1    |
# | Executive Director and Co-Founder                                                              | 1    |
# | Venture Director                                                                               | 1    |
# | Associate Dean of Graduate Programs                                                            | 1    |
# | Investor                                                                                       | 1    |
# | Vice President, Global Corporate Responsibility                                                | 1    |
# | Business Development Executive                                                                 | 1    |
# | Presenter Recruitment                                                                          | 1    |
# | Director of Operations                                                                         | 1    |
# | Chief Optimizer                                                                                | 1    |
# | Senior Marketing Manager, Channels and International                                           | 1    |
# | Program Manager, Natural Gas Vehicles                                                          | 1    |
# | Director of Marketing                                                                          | 1    |
# | Ph.D. Candidate                                                                                | 1    |
# | Associate - M&A, Restructuring and Recapitalization Advisory                                   | 1    |
# | Advisory Board Member                                                                          | 1    |
# | Manager of Policy and External Relations                                                       | 1    |
# | Managing Director, Rice Alliance for Technology & Entrepreneurship                             | 1    |
# | Director, Retail Analytics                                                                     | 1    |
# | Chief Operating Officer & Interim Executive Director                                           | 1    |
# | WARF Catalyst                                                                                  | 1    |
# | Founding Member                                                                                | 1    |
# | Co-Founder & Director of Business Development                                                  | 1    |
# | Director of International Business Development                                                 | 1    |
# | Founder & Partner                                                                              | 1    |
# | Research Manager, Institute for Strategy and Competitiveness                                   | 1    |
# | Principal Licensing Specialist                                                                 | 1    |
# | Deputy Laboratory Director for Programs                                                        | 1    |
# | Materials Scientist                                                                            | 1    |
# | Manager - Swap Market Regulation                                                               | 1    |
# | Technology Development Manager                                                                 | 1    |
# | Vice President of Strategy and External Relations                                              | 1    |
# | Director of Strategy, Danfoss Power Electronics                                                | 1    |
# | Cofounder and Chief Executive Officer                                                          | 1    |
# | MBA Candidate                                                                                  | 1    |
# | clerk                                                                                          | 1    |
# | Vice President, Global Director of Energy & Sustainability                                     | 1    |
# | Director of Venture Technology                                                                 | 1    |
# | Director of Communications, Education and Public Affairs                                       | 1    |
# | President, Chief Technology Officer, & Co-Founder                                              | 1    |
# | Retired                                                                                        | 1    |
# | Vice President Strategic Value Chain                                                           | 1    |
# | Science and Technology Fellow                                                                  | 1    |
# | Technical Consultant                                                                           | 1    |
# | Board President                                                                                | 1    |
# | Senior Advisor on Social Ventures                                                              | 1    |
# | Board member, chief financial officer                                                          | 1    |
# | Director, EnterpriseWorks Chicago                                                              | 1    |
# | Founder & Director Energy For One World                                                        | 1    |
# | Owner                                                                                          | 1    |
# | Acting Director of Operations and Outreach                                                     | 1    |
# | Board Of Directors                                                                             | 1    |
# | Project Leader - Innovation, Partnering, and Outreach                                          | 1    |
# | Founder and Managing Director                                                                  | 1    |
# | Executive Chairman                                                                             | 1    |
# | Operations Manager, Chicago Innovation Mentors (CIM)                                           | 1    |
# | Principal Investigator                                                                         | 1    |
# | Head of Growth                                                                                 | 1    |
# | Electrical & Computer Engineering                                                              | 1    |
# | Student Affairs Manager, Erb Institute                                                         | 1    |
# | Board                                                                                          | 1    |
# | Chief Operating Officer                                                                        | 1    |
# | Project Manager                                                                                | 1    |
# | Director                                                                                       | 1    |
# | Executive Director of ChicagoNEXT                                                              | 1    |
# | Policy Associate                                                                               | 1    |
# | Chief Product Officer                                                                          | 1    |
# | Chair of the Board                                                                             | 1    |
# | Director - New Business Development                                                            | 1    |
# | Venture Partner                                                                                | 1    |
# | Market Development                                                                             | 1    |
# | Director of Strategy, Station A                                                                | 1    |
# | Director, Corporate Development                                                                | 1    |
# | Customer Service Manager                                                                       | 1    |
# | Board Member and Co-founder                                                                    | 1    |
# | Advanced Micro Devices                                                                         | 1    |
# | Business Mentor                                                                                | 1    |
# | Director Capital Introductions & Project Finance                                               | 1    |
# | Assistant Director of Operations                                                               | 1    |
# | Distinguished Professor                                                                        | 1    |
# | Liaison to the City of Detroit                                                                 | 1    |
# | Chief of Staff                                                                                 | 1    |
# | Infrastructure Architect & Engineer                                                            | 1    |
# | Principal Consultant                                                                           | 1    |
# | Mergers & Acquisitions                                                                         | 1    |
# | Intellectual Property and Business Development Manager                                         | 1    |
# | Business Development                                                                           | 1    |
# | Director of Programming and Outreach                                                           | 1    |
# | Special Projects Advisor                                                                       | 1    |
# | MBA Candidate, Class of 2014                                                                   | 1    |
# | Chief Executive Officer and Chairman of the Board                                              | 1    |
# | Seeking Opportunity                                                                            | 1    |
# | Senior Communications Specialist, Commercial Distribution Finance                              | 1    |
# | Creator                                                                                        | 1    |
# | Faculty - SIPA, CBS, and Earth Institute; Director - Energy & Environment Concentration - SIPA | 1    |
# | Vice President, Products                                                                       | 1    |
# | Director, Business Development and Finance                                                     | 1    |
# | General manager                                                                                | 1    |
# | Application Specialist                                                                         | 1    |
# | Senior Vice President, Energy Procurement                                                      | 1    |
# | Vice President, New Ventures & Capital Formation                                               | 1    |
# | Founder & Chief Executive Officer                                                              | 1    |
# | Director - Economics, Exposure, and Technology Division                                        | 1    |
# | Visiting Scholar                                                                               | 1    |
# | Director, Energy Services                                                                      | 1    |
# | Senior Exhibition Developer                                                                    | 1    |
# | Senior Director                                                                                | 1    |
# | Private Equity Lab Intern                                                                      | 1    |
# | Law Professor                                                                                  | 1    |
# | Vice President, Investment Banking                                                             | 1    |
# | Senior Automated Trade Desk Operator                                                           | 1    |
# | Senior Project Manager                                                                         | 1    |
# | Demand Generation                                                                              | 1    |
# | Venture Advisor                                                                                | 1    |
# | Manager, Commercialization Program                                                             | 1    |
# | Executive Director                                                                             | 1    |
# | Architect and Manager                                                                          | 1    |
# | partner                                                                                        | 1    |
# | Senior Financial Analyst - Product Development                                                 | 1    |
# | Chief Sustainability Officer                                                                   | 1    |
# | Associate                                                                                      | 1    |
# | Head of Americas                                                                               | 1    |
# | Deputy Director of Advance                                                                     | 1    |
# | Board Observer                                                                                 | 1    |
# | Executive Management Committee                                                                 | 1    |
# | Senior Manager, Government and Regulatory Affairs                                              | 1    |
# | Quantitative Political Consultant                                                              | 1    |
# | Director, Yale Project on Climate Change Communication                                         | 1    |
# | Senior Associate                                                                               | 1    |
# | Senior Account Executive                                                                       | 1    |
# | Tech Transfer Specialist                                                                       | 1    |
# | Consultant                                                                                     | 1    |
# | Chief Executive Officer & Managing Director                                                    | 1    |
# | Associate Director, Marketing, Communications & External Relations                             | 1    |
# | Managing Partner                                                                               | 1    |
# | Managing Attorney                                                                              | 1    |
# | Co-Founder & Chief Executive Officer                                                           | 1    |
# | BMW EV and i Brand Marketing Manager                                                           | 1    |
# | Creative Director                                                                              | 1    |
# | Associate Laboratory Director - Innovation, Partnering & Outreach                              | 1    |
# | Co-Founder, Managing Partner                                                                   | 1    |
# | President & Founder                                                                            | 1    |
# | Managing Partners                                                                              | 1    |
# | Electrical Engineer                                                                            | 1    |
# +------------------------------------------------------------------------------------------------+------+
# +-------------------+------+
# | Token             | Freq |
# +-------------------+------+
# | Director          | 57   |
# | President         | 40   |
# | Chief             | 32   |
# | Officer           | 30   |
# | Executive         | 29   |
# | and               | 28   |
# | Vice              | 23   |
# | Development       | 18   |
# | Manager           | 18   |
# | Board             | 17   |
# | Managing          | 16   |
# | Senior            | 15   |
# | Founder           | 14   |
# | Co-Founder        | 13   |
# | Business          | 11   |
# | Member            | 10   |
# | Principal         | 10   |
# | Energy            | 9    |
# | Technology        | 9    |
# | Partner           | 8    |
# | Project           | 7    |
# | for               | 7    |
# | Associate         | 7    |
# | Advisor           | 7    |
# | Research          | 6    |
# | Venture           | 6    |
# | Marketing         | 6    |
# | Innovation        | 5    |
# | Operations        | 5    |
# | Consultant        | 5    |
# | the               | 5    |
# | Global            | 4    |
# | Professor         | 4    |
# | Co-founder        | 4    |
# | Affairs           | 4    |
# | Program           | 4    |
# | Specialist        | 4    |
# | Finance           | 4    |
# | Outreach          | 4    |
# | Strategy          | 4    |
# | Deputy            | 4    |
# | Candidate         | 3    |
# | Chairman          | 3    |
# | Advanced          | 3    |
# | External          | 3    |
# | Sustainability    | 3    |
# | Owner             | 3    |
# | Relations         | 3    |
# | Assistant         | 3    |
# | Market            | 3    |
# | Policy            | 3    |
# | Communications    | 3    |
# | Corporate         | 3    |
# | Designer          | 2    |
# | Entrepreneurship  | 2    |
# | New               | 2    |
# | SIPA              | 2    |
# | Programs          | 2    |
# | Ventures          | 2    |
# | Architect         | 2    |
# | Mentor            | 2    |
# | Partnering        | 2    |
# | Adjunct           | 2    |
# | International     | 2    |
# | Head              | 2    |
# | Institute         | 2    |
# | Residence         | 2    |
# | Committee         | 2    |
# | Laboratory        | 2    |
# | Engineer          | 2    |
# | Center            | 2    |
# | Acting            | 2    |
# | Electrical        | 2    |
# | Regulatory        | 2    |
# | Commercialization | 2    |
# | Advisory          | 2    |
# | Entrepreneur      | 2    |
# | Engineering       | 2    |
# | Special           | 2    |
# | Chicago           | 2    |
# | Product           | 2    |
# | MBA               | 2    |
# | Operating         | 2    |
# | Student           | 2    |
# | Capital           | 2    |
# +-------------------+------+

# %% [markdown]
# ## Example 8. Geocoding locations with Microsoft Bing

# %%
from geopy import geocoders

GEO_APP_KEY = 'AoB3zLIJSUio83UFmF_Pz8QgPo2m-_PawYEHI4FWJFioI77YKjaCv4WLP7l3mKON' # XXX: Get this from https://www.bingmapsportal.com
g = geocoders.Bing(GEO_APP_KEY)
print g.geocode("Nashville", exactly_one=False)
# Out:
# [Location((36.1678390503, -86.7781600952, 0.0)), Location((39.2085494995, -86.2481384277, 0.0)), Location((38.3436813354, -89.3826370239, 0.0)), Location((33.9479293823, -93.847038269, 0.0)), Location((35.9743309021, -77.9649505615, 0.0))]

# %% [markdown]
# ## Example 9. Geocoding locations of LinkedIn connections with Microsoft Bing

# %%
from geopy import geocoders

GEO_APP_KEY = 'AoB3zLIJSUio83UFmF_Pz8QgPo2m-_PawYEHI4FWJFioI77YKjaCv4WLP7l3mKON' # XXX: Get this from https://www.bingmapsportal.com
g = geocoders.Bing(GEO_APP_KEY)

transforms = [('Greater ', ''), (' Area', '')]

results = {}
for c in connections['values']:
    if not c.has_key('location'): continue
        
    transformed_location = c['location']['name']
    for transform in transforms:
        transformed_location = transformed_location.replace(*transform)
    geo = g.geocode(transformed_location, exactly_one=False)
    if geo == []: continue
    results.update({ c['location']['name'] : geo })
    
#locations were not serializable, so couldn't use json to print them.
for key in results:
    print key
    print results[key]
    print

#print json.dumps(results, indent=1)
# Out:
# Albany, New York Area
# [Location((42.651550293, -73.7552108765, 0.0))]
#
# Greater Milwaukee Area
# [Location((43.041809082, -87.9068374634, 0.0))]
#
# Miami/Fort Lauderdale Area
# [Location((26.089969635, -80.1362762451, 0.0))]
#
# China
# [Location((36.5530853271, 103.97543335, 0.0))]
#
# West Palm Beach, Florida Area
# [Location((26.714389801, -80.0531921387, 0.0))]

# %% [markdown]
# ## Example 10. Parsing out states from Bing geocoder results using a regular expression

# %%
import re

# Most results contain a response that can be parsed by
# picking out the first two consecutive upper case letters 
# as a clue for the state
pattern = re.compile('.*([A-Z]{2}).*')
    
def parseStateFromBingResult(r):
    result = pattern.search(r[0][0])
    if result == None: 
        print "Unresolved match:", r
        return "jQuery20306372330349404365_1425394647000?"
    elif len(result.groups()) == 1:
        print result.groups()
        return result.groups()[0]
    else:
        print "Unresolved match:", result.groups()
        return "???"

    
transforms = [('Greater ', ''), (' Area', '')]

results = {}
for c in connections['values']:
    if not c.has_key('location'): continue
    if not c['location']['country']['code'] == 'us': continue
        
    transformed_location = c['location']['name']
    for transform in transforms:
        transformed_location = transformed_location.replace(*transform)
    
    geo = g.geocode(transformed_location, exactly_one=False)
    if geo == []: continue
    parsed_state = parseStateFromBingResult(geo)
    if parsed_state != "???":
        results.update({c['location']['name'] : parsed_state})
    
print json.dumps(results, indent=1)
# Out:
# (u'FL',)
# (u'FL',)
# (u'FL',)
# (u'FL',)
# (u'FL',)
# (u'FL',)
# (u'FL',)
# (u'FL',)
# (u'FL',)
# (u'WI',)
# (u'FL',)
# (u'NY',)
# {
#  "Albany, New York Area": "NY",
#  "Miami/Fort Lauderdale Area": "FL",
#  "Greater Milwaukee Area": "WI",
#  "West Palm Beach, Florida Area": "FL"
# }

# %% [markdown]
# **Here's how to power a Cartogram visualization with the data from the "results" variable**

# %%
import os
import json
from IPython.display import IFrame
from IPython.core.display import display

# Load in a data structure mapping state names to codes.
# e.g. West Virginia is WV
codes = json.loads(open('resources/viz/states-codes.json').read())

from collections import Counter
c = Counter([r[1] for r in results.items()])
states_freqs = { codes[k] : v for (k,v) in c.items() }

# Lace in all of the other states and provide a minimum value for each of them
states_freqs.update({v : 0.5 for v in codes.values() if v not in states_freqs.keys() })

# Write output to file
f = open('resources/viz/states-freqs.json', 'w')
f.write(json.dumps(states_freqs, indent=1))
f.close()

# IPython Notebook can serve files and display them into
# inline frames. Prepend the path with the 'files' prefix

display(IFrame('files/resources/viz/cartogram.html', '100%', '600px'))
# Out:
#         <iframe
#             width="100%"
#             height=600px"
#             src="files/resources/viz/cartogram.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Example 11. Using NLTK to compute bigrams

# %%
import nltk
ceo_bigrams = nltk.bigrams("Chief Executive Officer".split(), pad_right=True, 
                                                              pad_left=True)
cto_bigrams = nltk.bigrams("Chief Technology Officer".split(), pad_right=True, 
                                                               pad_left=True)

print ceo_bigrams
print cto_bigrams
print len(set(ceo_bigrams).intersection(set(cto_bigrams)))
# Out:
# <generator object bigrams at 0x0000000014681DC8>
# <generator object bigrams at 0x00000000042D8990>
# 2

# %% [markdown]
# ## Example 12. Clustering job titles using a greedy heuristic

# %%
import os
import csv
from nltk.metrics.distance import jaccard_distance

# XXX: The "Outlook CSV" formatted file of connections from 
# http://www.linkedin.com/people/export-settings is at the following
# location: resources/my-linkedin/my_connections.csv

CSV_FILE = os.path.join("resources", "my_connections.csv")

# Tweak this distance threshold and try different distance calculations 
# during experimentation
DISTANCE_THRESHOLD = 0.5
DISTANCE = jaccard_distance

def cluster_contacts_by_title(csv_file):

    transforms = [
        ('Sr.', 'Senior'),
        ('Sr', 'Senior'),
        ('Jr.', 'Junior'),
        ('Jr', 'Junior'),
        ('CEO', 'Chief Executive Officer'),
        ('COO', 'Chief Operating Officer'),
        ('CTO', 'Chief Technology Officer'),
        ('CFO', 'Chief Finance Officer'),
        ('VP', 'Vice President'),
        ]

    separators = ['/', ' and ', '&']

    csvReader = csv.DictReader(open(csv_file), delimiter=',', quotechar='"')
    contacts = [row for row in csvReader]

    # Normalize and/or replace known abbreviations
    # and build up a list of common titles.

    all_titles = []
    for i, _ in enumerate(contacts):
        if contacts[i]['Job Title'] == '':
            contacts[i]['Job Titles'] = ['']
            continue
        titles = [contacts[i]['Job Title'].strip()]
        for title in titles:
            for separator in separators:
                if title.find(separator) >= 0:
                    titles.remove(title.strip())
                    titles.extend([title.strip() for title in title.split(separator)
                                  if title.strip() != ''])

        for transform in transforms:
            titles = [title.replace(*transform) for title in titles]
        contacts[i]['Job Titles'] = titles
        all_titles.extend(titles)

    all_titles = list(set(all_titles))

    clusters = {}
    for title1 in all_titles:
        clusters[title1] = []
        for title2 in all_titles:
            if title2 in clusters[title1] or clusters.has_key(title2) and title1 \
                in clusters[title2]:
                continue
            distance = DISTANCE(set(title1.split()), set(title2.split()))

            if distance < DISTANCE_THRESHOLD:
                clusters[title1].append(title2)

    # Flatten out clusters

    clusters = [clusters[title] for title in clusters if len(clusters[title]) > 1]

    # Round up contacts who are in these clusters and group them together

    clustered_contacts = {}
    for cluster in clusters:
        clustered_contacts[tuple(cluster)] = []
        for contact in contacts:
            for title in contact['Job Titles']:
                if title in cluster:
                    clustered_contacts[tuple(cluster)].append('%s %s'
                            % (contact['First Name'], contact['Last Name']))

    return clustered_contacts


clustered_contacts = cluster_contacts_by_title(CSV_FILE)
print clustered_contacts
for titles in clustered_contacts:
    common_titles_heading = 'Common Titles: ' + ', '.join(titles)

    descriptive_terms = set(titles[0].split())
    for title in titles:
        descriptive_terms.intersection_update(set(title.split()))
    descriptive_terms_heading = 'Descriptive Terms: ' \
        + ', '.join(descriptive_terms)
    print descriptive_terms_heading
    print '-' * max(len(descriptive_terms_heading), len(common_titles_heading))
    print '\n'.join(clustered_contacts[titles])
    print
# Out:
# {('Business Development Executive', 'Business Development'): ['Robert M. Whitson', 'Wayne Janisch', 'Marc Thrum'], ('Corporate Board Director', 'Board Director'): ['Laurie Benson', 'Dr. Christine Gulbranson'], ('Chairman of the Board', 'Chair of the Board'): ['Rick LeBlanc', 'Debra Shore'], ('Director, Business Development', 'Business Development'): ['Wayne Janisch', 'Daniel Sachs', 'Marc Thrum'], ('Managing Partner', 'Co-Founder, Managing Partner'): ['Alexandra Zaporozec', 'Ron Fleckman'], ('Interim Executive Director', 'Executive Director'): ['Justin F. Kaster', 'LeAnne Cabalka Tourtellotte', 'Caralynn Nowinski'], ('Business Development Manager', 'Business Development'): ['Brad Ullrick', 'Wayne Janisch', 'Marc Thrum'], ('Senior Vice President', 'Vice President'): ['Jeffrey Maters', 'John Poast', 'Jeremy Adelman', 'Chris McKissack, PE, PMP', 'Tom Poser', 'Adam Lerner', 'Shyam Desai', 'Marguerite Clark', 'Peter North', 'Heidi Levin'], ('Director, Market Development', 'Market Development'): ['Arabella Santiago', 'Emma Berndt'], ('Director of Operations', 'Assistant Director of Operations', 'Acting Director of Operations'): ['Bruno Vanzieleghem', 'Jeff Henderson', 'Noel Davis'], ('Advisory Board Member', 'Board Member'): ['Kevin Willer', 'Steven Collens', 'Amir Tehrani', 'Michael Marasco', 'Adam Koopersmith', 'John Regan', 'Kelly Schwedland', 'Pulakesh Mukherjee'], ('Assistant Director of Operations', 'Acting Director of Operations'): ['Bruno Vanzieleghem', 'Jeff Henderson'], ('Vice President Finance', 'Vice President'): ['Jeffrey Maters', 'Jeremy Adelman', 'Chris McKissack, PE, PMP', 'Tom Poser', 'Adam Lerner', 'Shyam Desai', 'Marguerite Clark', 'Ted Gladish', 'Peter North'], ('Director of International Business Development', 'Director of Business Development'): ['Adam Atkinson-Lewis', 'Mark Maloney'], ('Project Manager', 'Senior Project Manager'): ['Juan Andres Benatuil Wulff', 'Eric Michael Vazquez', 'Jonathan Gortat, MBA, CLP'], ('Chief Executive Officer', 'Co-Founder, Chief Executive Officer'): ['John Banta', 'Lee (George Leland) Edwards', 'Clay Parker', 'Jay Marhoefer', 'Rick LeBlanc', 'Jigar Shah', 'Errol Arkilic', 'Michael Gurin', 'Joe Kremer', 'Daphne Preuss', 'Ralph Shayne', 'Ankur Jain', 'Steve Johanns', 'Rodrigo Prudencio', 'Doug Morrison', 'Mark Forsyth', 'Gregg Mast', 'Scott Clavenna', 'Michael Reinhold', 'Richard Stuebi', 'Adam Rentschler']}
# Descriptive Terms: Development, Business
# -------------------------------------------------------------------
# Robert M. Whitson
# Wayne Janisch
# Marc Thrum
#
# Descriptive Terms: Director, Board
# -------------------------------------------------------
# Laurie Benson
# Dr. Christine Gulbranson
#
# Descriptive Terms: of, the, Board
# --------------------------------------------------------
# Rick LeBlanc
# Debra Shore
#
# Descriptive Terms: Development, Business
# -------------------------------------------------------------------
# Wayne Janisch
# Daniel Sachs
# Marc Thrum
#
# Descriptive Terms: Managing, Partner
# -------------------------------------------------------------
# Alexandra Zaporozec
# Ron Fleckman
#
# Descriptive Terms: Director, Executive
# -------------------------------------------------------------
# Justin F. Kaster
# LeAnne Cabalka Tourtellotte
# Caralynn Nowinski
#
# Descriptive Terms: Development, Business
# -----------------------------------------------------------------
# Brad Ullrick
# Wayne Janisch
# Marc Thrum
#
# Descriptive Terms: President, Vice
# ----------------------------------------------------
# Jeffrey Maters
# John Poast
# Jeremy Adelman
# Chris McKissack, PE, PMP
# Tom Poser
# Adam Lerner
# Shyam Desai
# Marguerite Clark
# Peter North
# Heidi Levin
#
# Descriptive Terms: Development, Market
# ---------------------------------------------------------------
# Arabella Santiago
# Emma Berndt
#
# Descriptive Terms: Director, of, Operations
# ------------------------------------------------------------------------------------------------------
# Bruno Vanzieleghem
# Jeff Henderson
# Noel Davis
#
# Descriptive Terms: Member, Board
# --------------------------------------------------
# Kevin Willer
# Steven Collens
# Amir Tehrani
# Michael Marasco
# Adam Koopersmith
# John Regan
# Kelly Schwedland
# Pulakesh Mukherjee
#
# Descriptive Terms: Director, of, Operations
# ------------------------------------------------------------------------------
# Bruno Vanzieleghem
# Jeff Henderson
#
# Descriptive Terms: President, Vice
# -----------------------------------------------------
# Jeffrey Maters
# Jeremy Adelman
# Chris McKissack, PE, PMP
# Tom Poser
# Adam Lerner
# Shyam Desai
# Marguerite Clark
# Ted Gladish
# Peter North
#
# Descriptive Terms: Director, of, Development, Business
# -----------------------------------------------------------------------------------------------
# Adam Atkinson-Lewis
# Mark Maloney
#
# Descriptive Terms: Project, Manager
# ------------------------------------------------------
# Juan Andres Benatuil Wulff
# Eric Michael Vazquez
# Jonathan Gortat, MBA, CLP
#
# Descriptive Terms: Chief, Executive, Officer
# ---------------------------------------------------------------------------
# John Banta
# Lee (George Leland) Edwards
# Clay Parker
# Jay Marhoefer
# Rick LeBlanc
# Jigar Shah
# Errol Arkilic
# Michael Gurin
# Joe Kremer
# Daphne Preuss
# Ralph Shayne
# Ankur Jain
# Steve Johanns
# Rodrigo Prudencio
# Doug Morrison
# Mark Forsyth
# Gregg Mast
# Scott Clavenna
# Michael Reinhold
# Richard Stuebi
# Adam Rentschler

# %% [markdown]
# **Incorporating random sampling can improve performance of the nested loops in Example 12**

# %%
import os
import csv
import random
from nltk.metrics.distance import jaccard_distance

# XXX: The "Outlook CSV" formatted file of connections from 
# http://www.linkedin.com/people/export-settings is at the following
# location: resources/my-linkedin/my_connections.csv

CSV_FILE = os.path.join("resources", "my_connections.csv")

# Tweak this distance threshold and try different distance calculations 
# during experimentation
DISTANCE_THRESHOLD = 0.5
DISTANCE = jaccard_distance

# Adjust sample size as needed to reduce the runtime of the
# nested loop that invokes the DISTANCE function
SAMPLE_SIZE = 500

def cluster_contacts_by_title(csv_file):

    transforms = [
        ('Sr.', 'Senior'),
        ('Sr', 'Senior'),
        ('Jr.', 'Junior'),
        ('Jr', 'Junior'),
        ('CEO', 'Chief Executive Officer'),
        ('COO', 'Chief Operating Officer'),
        ('CTO', 'Chief Technology Officer'),
        ('CFO', 'Chief Finance Officer'),
        ('VP', 'Vice President'),
        ]

    separators = ['/', ' and ', '&']

    csvReader = csv.DictReader(open(csv_file), delimiter=',', quotechar='"')
    contacts = [row for row in csvReader]

    # Normalize and/or replace known abbreviations
    # and build up list of common titles

    all_titles = []
    for i, _ in enumerate(contacts):
        if contacts[i]['Job Title'] == '':
            contacts[i]['Job Titles'] = ['']
            continue
        titles = [contacts[i]['Job Title'].strip()]
        for title in titles:
            for separator in separators:
                if title.find(separator) >= 0:
                    titles.remove(title.strip())
                    titles.extend([title.strip() for title in title.split(separator)
                                  if title.strip() != ''])

        for transform in transforms:
            titles = [title.replace(*transform) for title in titles]
        contacts[i]['Job Titles'] = titles
        all_titles.extend(titles)

    all_titles = list(set(all_titles))
    clusters = {}
    for title1 in all_titles:
        clusters[title1] = []
        for sample in xrange(SAMPLE_SIZE):
            title2 = all_titles[random.randint(0, len(all_titles)-1)]
            if title2 in clusters[title1] or clusters.has_key(title2) and title1 \
                in clusters[title2]:
                continue
            distance = DISTANCE(set(title1.split()), set(title2.split()))
            if distance < DISTANCE_THRESHOLD:
                clusters[title1].append(title2)

    # Flatten out clusters

    clusters = [clusters[title] for title in clusters if len(clusters[title]) > 1]

    # Round up contacts who are in these clusters and group them together

    clustered_contacts = {}
    for cluster in clusters:
        clustered_contacts[tuple(cluster)] = []
        for contact in contacts:
            for title in contact['Job Titles']:
                if title in cluster:
                    clustered_contacts[tuple(cluster)].append('%s %s'
                            % (contact['First Name'], contact['Last Name']))

    return clustered_contacts


clustered_contacts = cluster_contacts_by_title(CSV_FILE)
print clustered_contacts
for titles in clustered_contacts:
    common_titles_heading = 'Common Titles: ' + ', '.join(titles)

    descriptive_terms = set(titles[0].split())
    for title in titles:
        descriptive_terms.intersection_update(set(title.split()))
    descriptive_terms_heading = 'Descriptive Terms: ' \
        + ', '.join(descriptive_terms)
    print descriptive_terms_heading
    print '-' * max(len(descriptive_terms_heading), len(common_titles_heading))
    print '\n'.join(clustered_contacts[titles])
    print
# Out:
# {('Acting Director of Operations', 'Assistant Director of Operations', 'Director of Operations'): ['Bruno Vanzieleghem', 'Jeff Henderson', 'Noel Davis'], ('Director, Business Development', 'Business Development'): ['Wayne Janisch', 'Daniel Sachs', 'Marc Thrum'], ('Senior Project Manager', 'Project Manager'): ['Juan Andres Benatuil Wulff', 'Eric Michael Vazquez', 'Jonathan Gortat, MBA, CLP'], ('Co-Founder, Managing Partner', 'Managing Partner'): ['Alexandra Zaporozec', 'Ron Fleckman'], ('Vice President', 'Senior Vice President'): ['Jeffrey Maters', 'John Poast', 'Jeremy Adelman', 'Chris McKissack, PE, PMP', 'Tom Poser', 'Adam Lerner', 'Shyam Desai', 'Marguerite Clark', 'Peter North', 'Heidi Levin'], ('Interim Executive Director', 'Executive Director'): ['Justin F. Kaster', 'LeAnne Cabalka Tourtellotte', 'Caralynn Nowinski'], ('Business Development Manager', 'Business Development'): ['Brad Ullrick', 'Wayne Janisch', 'Marc Thrum'], ('Chair of the Board', 'Chairman of the Board'): ['Rick LeBlanc', 'Debra Shore'], ('Co-Founder, Chief Executive Officer', 'Chief Executive Officer'): ['John Banta', 'Lee (George Leland) Edwards', 'Clay Parker', 'Jay Marhoefer', 'Rick LeBlanc', 'Jigar Shah', 'Errol Arkilic', 'Michael Gurin', 'Joe Kremer', 'Daphne Preuss', 'Ralph Shayne', 'Ankur Jain', 'Steve Johanns', 'Rodrigo Prudencio', 'Doug Morrison', 'Mark Forsyth', 'Gregg Mast', 'Scott Clavenna', 'Michael Reinhold', 'Richard Stuebi', 'Adam Rentschler'], ('Business Development', 'Business Development Executive'): ['Robert M. Whitson', 'Wayne Janisch', 'Marc Thrum'], ('Assistant Director of Operations', 'Acting Director of Operations'): ['Bruno Vanzieleghem', 'Jeff Henderson'], ('Market Development', 'Director, Market Development'): ['Arabella Santiago', 'Emma Berndt'], ('Director of International Business Development', 'Director of Business Development'): ['Adam Atkinson-Lewis', 'Mark Maloney']}
# Descriptive Terms: Director, of, Operations
# ------------------------------------------------------------------------------------------------------
# Bruno Vanzieleghem
# Jeff Henderson
# Noel Davis
#
# Descriptive Terms: Development, Business
# -------------------------------------------------------------------
# Wayne Janisch
# Daniel Sachs
# Marc Thrum
#
# Descriptive Terms: Project, Manager
# ------------------------------------------------------
# Juan Andres Benatuil Wulff
# Eric Michael Vazquez
# Jonathan Gortat, MBA, CLP
#
# Descriptive Terms: Managing, Partner
# -------------------------------------------------------------
# Alexandra Zaporozec
# Ron Fleckman
#
# Descriptive Terms: President, Vice
# ----------------------------------------------------
# Jeffrey Maters
# John Poast
# Jeremy Adelman
# Chris McKissack, PE, PMP
# Tom Poser
# Adam Lerner
# Shyam Desai
# Marguerite Clark
# Peter North
# Heidi Levin
#
# Descriptive Terms: Director, Executive
# -------------------------------------------------------------
# Justin F. Kaster
# LeAnne Cabalka Tourtellotte
# Caralynn Nowinski
#
# Descriptive Terms: Development, Business
# -----------------------------------------------------------------
# Brad Ullrick
# Wayne Janisch
# Marc Thrum
#
# Descriptive Terms: of, the, Board
# --------------------------------------------------------
# Rick LeBlanc
# Debra Shore
#
# Descriptive Terms: Chief, Executive, Officer
# ---------------------------------------------------------------------------
# John Banta
# Lee (George Leland) Edwards
# Clay Parker
# Jay Marhoefer
# Rick LeBlanc
# Jigar Shah
# Errol Arkilic
# Michael Gurin
# Joe Kremer
# Daphne Preuss
# Ralph Shayne
# Ankur Jain
# Steve Johanns
# Rodrigo Prudencio
# Doug Morrison
# Mark Forsyth
# Gregg Mast
# Scott Clavenna
# Michael Reinhold
# Richard Stuebi
# Adam Rentschler
#
# Descriptive Terms: Development, Business
# -------------------------------------------------------------------
# Robert M. Whitson
# Wayne Janisch
# Marc Thrum
#
# Descriptive Terms: Director, of, Operations
# ------------------------------------------------------------------------------
# Bruno Vanzieleghem
# Jeff Henderson
#
# Descriptive Terms: Development, Market
# ---------------------------------------------------------------
# Arabella Santiago
# Emma Berndt
#
# Descriptive Terms: Director, of, Development, Business
# -----------------------------------------------------------------------------------------------
# Adam Atkinson-Lewis
# Mark Maloney

# %% [markdown]
# **How to export data (contained in the "clustered contacts" variable) to power faceted display as outlined in Figure 3.**

# %%
import json
import os
from IPython.display import IFrame
from IPython.core.display import display

data = {"label" : "name", "temp_items" : {}, "items" : []} 
for titles in clustered_contacts:
    descriptive_terms = set(titles[0].split())
    for title in titles:
        descriptive_terms.intersection_update(set(title.split()))
    descriptive_terms = ', '.join(descriptive_terms)

    if data['temp_items'].has_key(descriptive_terms):
        data['temp_items'][descriptive_terms].extend([{'name' : cc } for cc 
            in clustered_contacts[titles]])
    else:
        data['temp_items'][descriptive_terms] = [{'name' : cc } for cc 
            in clustered_contacts[titles]]

for descriptive_terms in data['temp_items']:
    data['items'].append({"name" : "%s (%s)" % (descriptive_terms, 
        len(data['temp_items'][descriptive_terms]),),
                              "children" : [i for i in 
                              data['temp_items'][descriptive_terms]]})

del data['temp_items']

# Open the template and substitute the data

TEMPLATE = 'resources/viz/dojo_tree.html.template'                                                
OUT = 'resources/viz/dojo_tree.html'

viz_file = 'files/resources/viz/dojo_tree.html'

t = open(TEMPLATE).read()
f = open(OUT, 'w')
f.write(t % json.dumps(data, indent=4))
f.close()

# IPython Notebook can serve files and display them into
# inline frames. Prepend the path with the 'files' prefix

display(IFrame(viz_file, '400px', '600px'))
# Out:
#         <iframe
#             width="400px"
#             height=600px"
#             src="files/resources/viz/dojo_tree.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# **How to export data to power a dendogram and node-link tree visualization as outlined in Figure 4.**

# %%
import os
import csv
import random
from nltk.metrics.distance import jaccard_distance
from cluster import HierarchicalClustering

# XXX: The "Outlook CSV" formatted file of connections from 
# http://www.linkedin.com/people/export-settings is at the following
# location: resources/my-linkedin/my_connections.csv

CSV_FILE = os.path.join("resources", 'my_connections_comb.csv')

OUT_FILE = 'resources/viz/d3-data.json'

# Tweak this distance threshold and try different distance calculations 
# during experimentation
DISTANCE_THRESHOLD = 0.5
DISTANCE = jaccard_distance

# Adjust sample size as needed to reduce the runtime of the
# nested loop that invokes the DISTANCE function
SAMPLE_SIZE = 500

def cluster_contacts_by_title(csv_file):

    transforms = [
        ('Sr.', 'Senior'),
        ('Sr', 'Senior'),
        ('Jr.', 'Junior'),
        ('Jr', 'Junior'),
        ('CEO', 'Chief Executive Officer'),
        ('COO', 'Chief Operating Officer'),
        ('CTO', 'Chief Technology Officer'),
        ('CFO', 'Chief Finance Officer'),
        ('VP', 'Vice President'),
        ]

    separators = ['/', 'and', '&']

    csvReader = csv.DictReader(open(csv_file), delimiter=',', quotechar='"')
    contacts = [row for row in csvReader]

    # Normalize and/or replace known abbreviations
    # and build up list of common titles

    all_titles = []
    for i, _ in enumerate(contacts):
        if contacts[i]['Job Title'] == '':
            contacts[i]['Job Titles'] = ['']
            continue
        titles = [contacts[i]['Job Title']]
        for title in titles:
            for separator in separators:
                if title.find(separator) >= 0:
                    titles.remove(title)
                    titles.extend([title.strip() for title in title.split(separator)
                                  if title.strip() != ''])

        for transform in transforms:
            titles = [title.replace(*transform) for title in titles]
        contacts[i]['Job Titles'] = titles
        all_titles.extend(titles)

    all_titles = list(set(all_titles))
    
    # Define a scoring function
    def score(title1, title2): 
        return DISTANCE(set(title1.split()), set(title2.split()))

    # Feed the class your data and the scoring function
    hc = HierarchicalClustering(all_titles, score)

    # Cluster the data according to a distance threshold
    clusters = hc.getlevel(DISTANCE_THRESHOLD)

    # Remove singleton clusters
    clusters = [c for c in clusters if len(c) > 1]

    # Round up contacts who are in these clusters and group them together

    clustered_contacts = {}
    for cluster in clusters:
        clustered_contacts[tuple(cluster)] = []
        for contact in contacts:
            for title in contact['Job Titles']:
                if title in cluster:
                    clustered_contacts[tuple(cluster)].append('%s %s'
                            % (contact['First Name'], contact['Last Name']))

    return clustered_contacts

def display_output(clustered_contacts):
    
    for titles in clustered_contacts:
        common_titles_heading = 'Common Titles: ' + ', '.join(titles)

        descriptive_terms = set(titles[0].split())
        for title in titles:
            descriptive_terms.intersection_update(set(title.split()))
        descriptive_terms_heading = 'Descriptive Terms: ' \
            + ', '.join(descriptive_terms)
        print descriptive_terms_heading
        print '-' * max(len(descriptive_terms_heading), len(common_titles_heading))
        print '\n'.join(clustered_contacts[titles])
        print

def write_d3_json_output(clustered_contacts):
    
    json_output = {'name' : 'My LinkedIn', 'children' : []}

    for titles in clustered_contacts:

        descriptive_terms = set(titles[0].split())
        for title in titles:
            descriptive_terms.intersection_update(set(title.split()))

        json_output['children'].append({'name' : ', '.join(descriptive_terms)[:30], 
                                    'children' : [ {'name' : c.decode('utf-8', 'replace')} for c in clustered_contacts[titles] ] } )
    
        f = open(OUT_FILE, 'w')
        f.write(json.dumps(json_output, indent=1))
        f.close()
    
clustered_contacts = cluster_contacts_by_title(CSV_FILE)
display_output(clustered_contacts)
write_d3_json_output(clustered_contacts)
# Out:
#   File "<ipython-input-44-93a39fc6c413>", line 108
#     json_output = {'name' : 'children' : []}
#                                        ^
# SyntaxError: invalid syntax

# %% [markdown]
# **Once you've run the code and produced the output for the dendogram and node-link tree visualizations, here's one way to serve it.**

# %%
import os
from IPython.display import IFrame
from IPython.core.display import display

# IPython Notebook can serve files and display them into
# inline frames. Prepend the path with the 'files' prefix

viz_file = 'files/resources/viz/node_link_tree.html'

# XXX: Another visualization you could try:
#viz_file = 'files/resources/my-linkedin/viz/dendogram.html'

display(IFrame(viz_file, '100%', '600px'))
# Out:
#         <iframe
#             width="100%"
#             height=600px"
#             src="files/resources/viz/node_link_tree.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Example 13. Clustering your LinkedIn professional network based upon the locations of your connections and emitting KML output for visualization with Google Earth

# %%
import os
import sys
import json
from urllib2 import HTTPError
from geopy import geocoders
from cluster import KMeansClustering
import centroid

# A helper function to munge data and build up an XML tree.
# It references some code tucked away in another directory, so we have to
# add that directory to the PYTHONPATH for it to be picked up.
sys.path.append(os.path.join(os.getcwd(), "resources"))
from linkedin__kml_utility import createKML

# XXX: Try different values for K to see the difference in clusters that emerge

K = 3

# XXX: Get an API key and pass it in here. See https://www.bingmapsportal.com.
GEO_API_KEY = 'AvxKTzRCIzr7Vei2p7PAmuT4KYjO0qnJyhmB18Zk1iMFljxOv-e4d_ZP2HRpPnSB'
g = geocoders.Bing(GEO_API_KEY)

# Load this data from where you've previously stored it

CONNECTIONS_DATA = 'resources/linkedin_connections.json'

OUT_FILE = "resources/viz/linkedin_clusters_kmeans.kml"

# Open up your saved connections with extended profile information
# or fetch them again from LinkedIn if you prefer

connections = json.loads(open(CONNECTIONS_DATA).read())['values']

locations = [c['location']['name'] for c in connections if c.has_key('location')]

# Some basic transforms may be necessary for geocoding services to function properly
# Here are a couple that seem to help.

transforms = [('Greater ', ''), (' Area', '')]

# Step 1 - Tally the frequency of each location

coords_freqs = {}
for location in locations:

    if not c.has_key('location'): continue
    
    # Avoid unnecessary I/O and geo requests by building up a cache

    if coords_freqs.has_key(location):
        coords_freqs[location][1] += 1
        continue
    transformed_location = location

    for transform in transforms:
        transformed_location = transformed_location.replace(*transform)
        
        # Handle potential I/O errors with a retry pattern...
        
        while True:
            num_errors = 0
            try:
                results = g.geocode(transformed_location, exactly_one=False)
                break
            except HTTPError, e:
                num_errors += 1
                if num_errors >= 3:
                    sys.exit()
                print >> sys.stderr, e
                print >> sys.stderr, 'Encountered an urllib2 error. Trying again...'
                
        if results:
            for result in results:
                # Each result is of the form ("Description", (X,Y))
                coords_freqs[location] = [result[1], 1]
                break # Disambiguation strategy is "pick first"

# Step 2 - Build up data structure for converting locations to KML            
            
# Here, you could optionally segment locations by continent or country
# so as to avoid potentially finding a mean in the middle of the ocean.
# The k-means algorithm will expect distinct points for each contact, so
# build out an expanded list to pass it.

expanded_coords = []
for label in coords_freqs:
    # Flip lat/lon for Google Earth
    ((lat, lon), f) = coords_freqs[label]
    expanded_coords.append((label, [(lon, lat)] * f))

# No need to clutter the map with unnecessary placemarks...

kml_items = [{'label': label, 'coords': '%s,%s' % coords[0]} for (label,
             coords) in expanded_coords]

# It would also be helpful to include names of your contacts on the map

for item in kml_items:
    item['contacts'] = '\n'.join(['%s %s.' % (c['firstName'], c['lastName'])
        for c in connections if c.has_key('location') and 
                                c['location']['name'] == item['label']])

# Step 3 - Cluster locations and extend the KML data structure with centroids
    
cl = KMeansClustering([coords for (label, coords_list) in expanded_coords
                      for coords in coords_list])

centroids = [{'label': 'CENTROID', 'coords': '%s,%s' % centroid(c)} for c in
             cl.getclusters(K)]

kml_items.extend(centroids)

# Step 4 - Create the final KML output and write it to a file

kml = createKML(kml_items)

f = open(OUT_FILE, 'w')
f.write(kml)
f.close()

print 'Data written to ' + OUT
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-21-98334cb55341> in <module>()
#      11 # add that directory to the PYTHONPATH for it to be picked up.
#      12 sys.path.append(os.path.join(os.getcwd(), "resources"))
# ---> 13 from linkedin__kml_utility import createKML
#      14
#      15 # XXX: Try different values for K to see the difference in clusters that emerge
#
# ImportError: No module named linkedin__kml_utility
